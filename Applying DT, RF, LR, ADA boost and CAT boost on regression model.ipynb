# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("market_data.csv")

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.Item_Weight.mode()
# Out:
# 0    12.15
# dtype: float64

# %%
data.Item_Weight = data.Item_Weight.fillna(12.15)

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.Outlet_Size.mode()
# Out:
# 0    Medium
# dtype: object

# %%
data.Outlet_Size = data.Outlet_Size.fillna("Medium")

# %%
data.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
out = data.Item_Outlet_Sales

# %%
data.Outlet_Establishment_Year.max()
# Out:
# 2009

# %%
data.Outlet_Establishment_Year = data.Outlet_Establishment_Year.max() - data.Outlet_Establishment_Year

# %%
# Out:
# 0       10
# 1        0
# 2       10
# 3       11
# 4       22
# 5        0
# 6       22
# 7       24
# 8        7
# 9        2
# 10      10
# 11      12
# 12      10
# 13      12
# 14      22
# 15      12
# 16       0
# 17      10
# 18      24
# 19       5
# 20      22
# 21      24
# 22       5
# 23      24
# 24      12
# 25       2
# 26       5
# 27      22
# 28      11
# 29      24
#         ..
# 8493     2
# 8494     2
# 8495     5
# 8496     2
# 8497     5
# 8498     0
# 8499     5
# 8500     2
# 8501     2
# 8502     7
# 8503     5
# 8504    24
# 8505     0
# 8506     0
# 8507     5
# 8508     7
# 8509    11
# 8510     5
# 8511     0
# 8512    22
# 8513     5
# 8514     7
# 8515     0
# 8516     0
# 8517    12
# 8518    22
# 8519     7
# 8520     5
# 8521     0
# 8522    12
# Name: Outlet_Establishment_Year, Length: 8523, dtype: int64

# %%
data.Outlet_Identifier.nunique()
# Out:
# 10

# %%
inp = data.drop(columns= ["Item_Outlet_Sales","Item_Identifier"], axis =1 )

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain,ytest = train_test_split(inp, out, test_size = 0.3, random_state = 48)

# %%
inp = pd.get_dummies(inp)

# %%
inp.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                         10
# 1         5.92         0.019278   48.2692                          0
# 2        17.50         0.016760  141.6180                         10
# 3        19.20         0.000000  182.0950                         11
# 4         8.93         0.000000   53.8614                         22
#
#    Item_Fat_Content_LF  Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  \
# 0                    0                         1                         0
# 1                    0                         0                         1
# 2                    0                         1                         0
# 3                    0                         0                         1
# 4                    0                         1                         0
#
#    Item_Fat_Content_low fat  Item_Fat_Content_reg  Item_Type_Baking Goods  \
# ...

# %%
xtrain.head()
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 343        20.250         0.026006  180.9976                          7
# 3400       17.700         0.000000  183.5924                          5
# 1507       15.000         0.026950  220.9456                          0
# 2474        6.525         0.090296   84.6882                         12
# 2168       14.000         0.031444   53.7640                          2
#
#       Item_Fat_Content_LF  Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  \
# 343                     0                         1                         0
# 3400                    0                         0                         1
# 1507                    0                         0                         1
# 2474                    0                         1                         0
# 2168                    0                         0                         0
#
# ...

# %%
ytrain.head()
# Out:
# 343     2716.4640
# 3400    7033.5112
# 1507    1768.3648
# 2474     601.2174
# 2168     798.9600
# Name: Item_Outlet_Sales, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %%
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
mse = mean_squared_error(ytest,ypred)

# %%
mse
# Out:
# 2556151.448935183

# %%
r2 = r2_score(ytest,ypred)
r2
# Out:
# 0.18199270677587476

# %%
rsme = mse**0.5

# %%
rsme
# Out:
# 1598.7968754457781

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
lm.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
ypredlm = lm.predict(xtest)

# %%
mselm = mean_squared_error(ytest,ypredlm)

# %%
mselm
# Out:
# 1394455.0374487257

# %%
r2lm = r2_score(ytest,ypredlm)
r2lm
# Out:
# 0.5537532053582548

# %%
rmselm = mselm**0.5

# %%
rmselm
# Out:
# 1180.870457522215

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
rf.fit(xtrain,ytrain)
# Out:
# C:\Users\Alwin\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
ypredrf = rf.predict(xtest)

# %%
mserf = mean_squared_error(ytest,ypredrf)

# %%
mserf
# Out:
# 1543761.4592686566

# %%
mserf**0.5
# Out:
# 1242.481975430089

# %%
r2rf = r2_score(ytest,ypredrf)
r2rf
# Out:
# 0.5059728823164498

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor(DecisionTreeRegressor(max_depth=2))
ada.fit(xtrain,ytrain)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-20a9c09800fe> in <module>
#       1 from sklearn.ensemble import AdaBoostRegressor
# ----> 2 ada = AdaBoostRegressor(DecisionTreeRegressor(max_depth=2))
#       3 ada.fit(xtrain,ytrain)
#
# NameError: name 'DecisionTreeRegressor' is not defined

# %%
ypredada = ada.predict(xtest)

# %%
mseada = mean_squared_error(ytest, ypredada)

# %%
mseada

# %%
rmseada = mseada**0.5

# %%
rmseada
# Out:
# 1333.9779421615897

# %%
r2ada = r2_score(ytest,ypredada)

# %%
r2ada
# Out:
# 0.4980337019460479

# %%
from catboost import CatBoostRegressor
cat = CatBoostRegressor()
cat.fit(xtrain,ytrain)
# Out:
# 0:	learn: 1652.7307301	total: 59ms	remaining: 58.9s
# 1:	learn: 1626.6492635	total: 99.3ms	remaining: 49.5s
# 2:	learn: 1601.7098358	total: 135ms	remaining: 45s
# 3:	learn: 1577.8670487	total: 192ms	remaining: 47.8s
# 4:	learn: 1553.7484937	total: 240ms	remaining: 47.8s
# 5:	learn: 1533.4368984	total: 284ms	remaining: 47.1s
# 6:	learn: 1511.0946645	total: 326ms	remaining: 46.3s
# 7:	learn: 1489.7157327	total: 361ms	remaining: 44.7s
# 8:	learn: 1470.6983910	total: 392ms	remaining: 43.2s
# 9:	learn: 1451.8090440	total: 423ms	remaining: 41.8s
# 10:	learn: 1433.3326126	total: 460ms	remaining: 41.3s
# 11:	learn: 1414.7733471	total: 506ms	remaining: 41.7s
# 12:	learn: 1397.5567105	total: 541ms	remaining: 41.1s
# 13:	learn: 1380.9521947	total: 572ms	remaining: 40.3s
# 14:	learn: 1365.9900247	total: 605ms	remaining: 39.7s
# 15:	learn: 1351.6254344	total: 637ms	remaining: 39.2s
# 16:	learn: 1337.4505635	total: 674ms	remaining: 38.9s
# 17:	learn: 1323.8725063	total: 725ms	remaining: 39.6s
# ...

# %%
ypredcat = cat.predict(xtest)

# %%
msecat = mean_squared_error(ytest,ypredcat)

# %%
rmsecat = msecat**0.5

# %%
rmsecat
# Out:
# 1139.7998859846473
